# %%
from IPython.display import display, HTML

display(HTML("""
<style>
    /* 1. UMUMIY KONTEYNER VA SHRIFT */
    .rendered_html, .jp-RenderedHTMLCommon, .jp-RenderedMarkdown {
        font-family: "Times New Roman", Times, serif !important;
        color: black !important;
        font-feature-settings: "kern" 1, "liga" 1, "clig" 1, "dlig" 1 !important;
        -webkit-font-smoothing: antialiased !important;
    }

    /* 2. MATNLAR: 1.5 oraliq, abzats va ro‘yxatlar */
    .rendered_html p, .jp-RenderedHTMLCommon p {
        font-family: "Times New Roman", Times, serif !important;
        font-size: 14pt !important;
        line-height: 1.5 !important;
        text-align: justify !important;
        text-indent: 1.25cm !important; /* Faqat p uchun abzats */
        margin: 0 !important;
    }

    /* Ro‘yxatlar uchun maxsus (nuqtalarni qaytarish) */
    .rendered_html ul, .jp-RenderedHTMLCommon ul {
        list-style-type: disc !important;
        margin-left: 2.5cm !important; /* Nuqtalar ko‘rinishi uchun surish */
        padding: 0 !important;
        text-indent: 0 !important;
    }

    .rendered_html li, .jp-RenderedHTMLCommon li {
        display: list-item !important; /* Block-dan list-item-ga qaytarish */
        font-family: "Times New Roman", Times, serif !important;
        font-size: 14pt !important;
        line-height: 1.5 !important;
        text-indent: 0 !important;
        margin: 0 !important;
    }

    .rendered_html p, .jp-RenderedHTMLCommon p {
        text-indent: 1.25cm !important;
    }

    /* 3. SARLAVHALAR: Markazda */
    .rendered_html h1, .jp-RenderedHTMLCommon h1,
    .rendered_html h2, .jp-RenderedHTMLCommon h2,
    .rendered_html h3, .jp-RenderedHTMLCommon h3,
    .rendered_html h4, .jp-RenderedHTMLCommon h4 {
        font-family: "Times New Roman", Times, serif !important;
        text-align: center !important;
        text-indent: 0 !important;
        margin: 0.5em 0 !important;
        font-weight: bold !important;
    }
    
    /* 4. KOD BLOKLARI VA PROMPTLARNI (In/Out) YASHIRISH */
    :root {
        --jp-code-font-size: 12pt !important;
    }

    /* "In [ ]" va "Out [ ]" yozuvlarini butunlay yo‘qotish */
    .jp-InputPrompt, .jp-OutputPrompt, .prompt, .input_prompt, .output_prompt {
        display: none !important;
        width: 0 !important;
        visibility: hidden !important;
    }

    /* Kod bloklarini chap chekkaga taqash */
    .jp-CodeCell .jp-Cell-inputWrapper, .cell.code_cell .input {
        margin-left: 0 !important;
        padding-left: 0 !important;
    }

    /* Sliderni yo‘qotish va qatorni majburan sindirish */
    .jp-CodeMirror, .CodeMirror, .CodeMirror-scroll, .CodeMirror-sizer, .CodeMirror-lines,
    .jp-OutputArea-output pre, .output_area pre, 
    .CodeMirror-code, .CodeMirror-line,
    code, kbd, samp {
        font-family: "Consolas", monospace !important;
        font-size: 12pt !important;
        text-indent: 0 !important;
        line-height: 1.3 !important;
        white-space: pre-wrap !important;
        word-wrap: break-word !important;
        word-break: break-all !important;
        overflow-x: visible !important;
        height: auto !important;
    }

    /* 5. BIRINCHI KATAKCHANI YASHIRISH VA TANLANGANDA OCHISH */
    /* Odatiy holatda mutlaqo yashirin va umuman joy egallamaydi */
    .jp-Notebook .jp-Cell:first-child:not(.jp-mod-selected), 
    .container div.cell.code_cell:first-of-type:not(.selected) {
        position: absolute !important;
        height: 0 !important;
        min-height: 0 !important;
        width: 0 !important;
        margin: 0 !important;
        padding: 0 !important;
        border: none !important;
        overflow: hidden !important;
        opacity: 0 !important;
        pointer-events: none !important;
        visibility: hidden !important;
    }


    /* Katakcha tanlanganda (Ctrl+A bosilganda) to‘liq ochiladi */
    .jp-Notebook .jp-Cell:first-child.jp-mod-selected,
    .container div.cell.code_cell:first-of-type.selected {
        position: relative !important;
        height: auto !important;
        width: 100% !important;
        opacity: 1 !important;
        overflow: visible !important;
        pointer-events: auto !important;
        visibility: visible !important;
    }
    
    /* Jadvallar ichidagi matnlarni 14pt qilish */
    .rendered_html table, .jp-RenderedHTMLCommon table,
    .rendered_html td, .jp-RenderedHTMLCommon td,
    .rendered_html th, .jp-RenderedHTMLCommon th {
        font-family: "Times New Roman", Times, serif !important;
        font-size: 14pt !important;
        line-height: 1.5 !important;
        color: black !important;
    }
    code, kbd, samp {
        white-space: nowrap !important;
    }
</style>
"""))
# Out:
# <style>
#     /* 1. UMUMIY KONTEYNER VA SHRIFT */
#     .rendered_html, .jp-RenderedHTMLCommon, .jp-RenderedMarkdown {
#         font-family: "Times New Roman", Times, serif !important;
#         color: black !important;
#         font-feature-settings: "kern" 1, "liga" 1, "clig" 1, "dlig" 1 !important;
#         -webkit-font-smoothing: antialiased !important;
#     }
#
#     /* 2. MATNLAR: 1.5 oraliq, abzats va ro‘yxatlar */
#     .rendered_html p, .jp-RenderedHTMLCommon p {
#         font-family: "Times New Roman", Times, serif !important;
#         font-size: 14pt !important;
#         line-height: 1.5 !important;
#         text-align: justify !important;
#         text-indent: 1.25cm !important; /* Faqat p uchun abzats */
#         margin: 0 !important;
#     }
#
#     /* Ro‘yxatlar uchun maxsus (nuqtalarni qaytarish) */
#     .rendered_html ul, .jp-RenderedHTMLCommon ul {
#         list-style-type: disc !important;
# ...

# %% [markdown]
# ### I bo‘lim — Nazariy: PyQt5 va Tarmoq dasturlash
#
# 1. `PyQt5` kutubxonasining asosiy imkoniyatlari va arxitekturasi. `Signal-slot` mexanizmi qanday ishlaydi va u an’anaviy `callback` usulidan nimasi bilan farq qiladi? Real dasturlashda qanday foyda beradi?
# 2. `QLabel` va `QLineEdit` vidjetlari o‘rtasidagi farqlar. Ularning xususiyatlari (shrift, o‘lcham, `setStyleSheet`) va foydalanish holatlari haqida amaliy misol bilan tushuntiring.
# 3. `QMessageBox` vidjetining vazifasi va turlari (`Information`, `Warning`, `Critical`, `Question`). Statik funksiyalar va piktogrammalardan foydalanish usullarini batafsil tushuntiring.
# 4. `PyQt5` da menyu yaratish jarayoni: `QMenuBar`, `QMenu`, `QAction` obyektlari va ular o‘rtasidagi munosabat. Keyboard shortcut va ikonkalar qo‘shish usullarini ko‘rsating.
# 5. `PyQt5` da matn muharriri dasturini loyihalash bosqichlari: kerakli vidjetlarni tanlash, layoutlar, fayllarni ochish/saqlash funksiyalarini qo‘shish va dasturni testlash.
# 6. `setStyleSheet()` metodi yordamida GUI elementlarini bezatish. CSS sintaksisi bilan o‘xshashlik va farqlar. Murakkab stillarni modullashtirish usullari.
# 7. `QtDesigner` dasturining imkoniyatlari: `drag-and-drop` dizayn, `.ui` fayllarni Python kodiga o‘tkazish (`pyuic5`) hamda qo‘lda kod yozish bilan solishtirganda afzalliklari.
# 8. Python `socket` moduli asosida `TCP` klient-server arxitekturasi. `socket()`, `bind()`, `listen()`, `accept()`, `connect()`, `send()`, `recv()`, `close()` metodlarining ketma-ketligi va vazifalari.
# 9. Tarmoq dasturlashda xatoliklarni boshqarish: `timeout`, `ConnectionRefused`, `BrokenPipe` holatlarini `try-except` bilan ushlash va foydalanuvchiga ma'lumot berish strategiyalari.
# 10. Ko‘p foydalanuvchili chat serverni qurish uchun qanday arxitektura tanlash kerak? `threading` va `asyncio` yondashuvlarini solishtiring, kichik loyiha uchun qaysi biri afzal va nima uchun?
# 11. `PyQt5` da `TCP socket` ustidan GUI boshqarish: `QThread` yoki `signal-slot` yordamida tarmoq hodisalarini GUI ga yetkazish. Nima uchun socket operatsiyalarini asosiy `thread`da bajarish xavfli?
# 12. Python ilovasini mustaqil yuklanuvchi faylga aylantirish: `PyInstaller` va `cx_Freeze` qiyosiy tahlili. `spec` fayl, `--onefile` rejimi, resurslarni to‘g‘ri paketlash muammolari.
# 13. `TCP` va `UDP` protokollarining farqlari, qaysi holatlarda qaysi birini ishlatish kerak? Chat ilovasi uchun `TCP` ni tanlaganingizning asosiy sabablari nima?
# 14. Klient-server dasturida ma’lumotni `encode/decode` qilish zaruriyati. `bytes` va `string` o‘rtasidagi farq, `UTF-8` kodlash va tarmoq orqali ma’lumot uzatishda ahamiyati.
# 15. `PyQt5` da rasmlarni joylashtirish usullari: `QPixmap`, `QLabel` orqali ko‘rsatish, resurslarni `.qrc` faylida boshqarish. Ikonkalar va fon rasmlarini dasturga qo‘shish amaliyoti.
#
# ---
#
# ### II bo‘lim — Nazariy: Mashinali o‘qitish
#
# 16. Mashinali o‘qitish va sun’iy intellektning farqlari. ML ning asosiy yo‘nalishlari: `supervised`, `unsupervised` va `reinforcement learning`. Hayotdan konkret misollar keltiring.
# 17. `NumPy` massivlari va Python ro‘yxatlarini solishtirish: xotira samaradorligi, vektorlashtirilgan amallar, `broadcasting` mexanizmi va ML da nima uchun `NumPy` afzal ekanligi.
# 18. `Pandas` `DataFrame` asosiy operatsiyalari: ma’lumotlarni yuklash, tozalash (`NaN` qiymatlar), filtrlash, guruhlash (`groupby`) va agregatsiya. Real datasetda amaliy qo‘llash.
# 19. Ma’lumotlarni mashinali o‘qitishga tayyorlash bosqichlari: yo‘qolgan qiymatlarni to‘ldirish, kategorik o‘zgaruvchilarni kodlash (`Label Encoding`, `One-Hot Encoding`), normalizatsiya va standartizatsiya.
# 20. `Matplotlib` yordamida chiziqli grafik, gistogramma va `scatter plot` yaratish. Grafik elementlarini sozlash: sarlavha, o‘q nomlari, ranglar, `legend` va grafikni saqlash.
# 21. `Seaborn` kutubxonasining `Matplotlib` dan ustunliklari: statistik vizualizatsiyalar, `heatmap`, `pairplot`, `boxplot`. Nima uchun ma’lumotlarni tushunishda vizualizatsiya muhim?
# 22. Chiziqli regressiya (`Linear Regression`) algoritmi: matematik asos (`OLS`), model o‘rgatish va bashorat qilish. Koeffitsiyentlarni talqin etish va modelni baholash (`R²`, `MSE`).
# 23. Logistik regressiya klassifikatsiya uchun qanday ishlaydi? `Sigmoid` funksiyasi, ikkilik chiqish va ehtimollik bahosi. Nima uchun u `Linear Regression` emas?
# 24. `K-means` klasterizatsiya algoritmining ishlash prinsipi: sentroidlar, iteratsiya va konvergensiya. `K` soni qanday tanlanadi? `Elbow method` nima?
# 25. Trening va test to‘plamiga bo‘lish (`train-test split`) nima uchun kerak? `Overfitting` va `underfitting` tushunchalari, ularni aniqlash va oldini olish usullari.
# 26. Qaror daraxti (`Decision Tree`) algoritmi: tugunlar, shoxlar va barglar. `Gini impurity` va `Information Gain` kriteriyalari. Daraxtning chuqurligi va `overfitting` munosabati.
# 27. `Random Forest` algoritmining `Decision Tree` dan ustunligi: `bagging` prinsipi, ko‘p daraxtlar va o‘rtacha ovoz berish. `Feature importance` ko‘rsatkichi nima va qanday ishlatiladi?
# 28. Klassifikatsiya modellarini baholash metrikalari: `Accuracy`, `Precision`, `Recall`, `F1-score` va `Confusion Matrix`. Bemorlarni tashxislashda `Precision` va `Recall` dan qaysi biri muhimroq?
# 29. Polinom regressiyasi va chiziqli regressiya o‘rtasidagi farq. Yuqori darajali polinomlar qanday muammolarga olib keladi? `Feature engineering` nima?
# 30. Sun’iy neyron tarmoqning biologik neyron bilan o‘xshashligi. `Perceptron` modeli, qatlamlar tuzilishi va aktivatsiya funksiyalari (`ReLU`, `Sigmoid`, `Softmax`).
# 31. `Backpropagation` algoritmi qanday ishlaydi? `Gradient descent`, o‘qish tezligi (`learning rate`) va uning modelga ta’siri. `Learning rate` juda katta yoki kichik bo‘lsa nima sodir bo‘ladi?
# 32. `Scikit-learn` kutubxonasining asosiy tuzilishi: `estimators`, `transformers`, `pipelines`. `fit()`, `predict()`, `score()` metodlari va ularning barcha algoritmlarda bir xil interfeys berishi.
# 33. `Cross-validation` (`k-fold`) nima va nima uchun bir martalik `train-test` bo‘linishidan yaxshiroq? `k=5` va `k=10` ning farqlari, kichik datasetlarda qo‘llash.
# 34. `Feature selection` (xususiyat tanlash) nima uchun muhim? Ko‘p xususiyat modelni qanday zaiflashtiradi? `Correlation matrix` va `feature importance` asosida xususiyat tanlash.
# 35. `Sklearn Pipeline` nima va nima uchun ishlatiladi? `Preprocessing` va model o‘rgatishni bitta obyektga birlashtirish afzalliklari va `data leakage` ni oldini olish.
# 36. `Jupyter Notebook` ning ma’lumot tahlilida tutgan o‘rni. Nima uchun ML loyihalarida odatiy Python skriptidan ko‘ra notebook afzal? Interaktiv tahlil imkoniyatlari.
# 37. `Titanic` yoki `Iris` kabi mashhur datasetlarni tahlil qilish jarayoni: `EDA` (`Exploratory Data Analysis`) bosqichlari, muhim xususiyatlarni aniqlash va dastlabki model qurish.
# 38. `Imbalanced dataset` muammosi: bir sinfning boshqasidan ancha ko‘p bo‘lishi. `Oversampling` (`SMOTE`), `undersampling` va `class_weight` parametrlari yordamida yechish usullari.
# 39. `Hyperparameter tuning` nima? `GridSearchCV` va `RandomizedSearchCV` farqlari, qidiruv strategiyalari va hisoblash narxi. `n_estimators` va `max_depth` uchun amaliy misol.
# 40. Regressiya modellarini baholash metrikalari: `MAE`, `MSE`, `RMSE` va `R²` ning afzalliklari va kamchiliklari. Uy narxini bashorat qilish modelida qaysi metrikani tanlash kerak?
# 41. `NumPy` da matritsalar bilan ishlash: `dot product`, `transpose`, `inverse`. Chiziqli algebra amallarini ML da qo‘llash va regressiya koeffitsiyentlarini analitik hisoblash.
# 42. `Pandas` da vaqt qatori (`time series`) ma’lumotlari bilan ishlash: `datetime` indeks, `resample`, `rolling window`. Savdo yoki ob-havo ma’lumotlarini tahlil qilishda qo‘llash.
# 43. `MLP` (`Multi-Layer Perceptron`) va oddiy logistik regressiya o‘rtasidagi farq. Qachon chuqur model, qachon sodda model ishlatish kerak? `Occam's razor` prinsipi ML da.
# 44. Ma’lumotlarni vizualizatsiya qilishning ML jarayonidagi roli: `outlier`larni aniqlash, `feature distributions`, korrelyatsiya tahlili. Yaxshi vizualizatsiya model sifatini qanday oshiradi?
# 45. Real loyihada ML modeli qurish to‘liq jarayoni: muammoni aniqlash, ma’lumot yig‘ish, `EDA`, `preprocessing`, model tanlash, o‘rgatish, baholash va ishga tushirish.
#
# ---
#
# ### III bo‘lim — Amaliy topshiriqlar
#
# 46. `[PyQt5]` Ikki son kiritib ularning yig‘indisi, ayirmasi, ko‘paytmasi va bo‘linmasini ko‘rsatadigan oddiy kalkulyator dasturini yozing. `QLineEdit`, `QPushButton` va `QLabel` dan foydalaning.
# 47. `[Socket]` Python da oddiy `echo-server` yarating: server klientdan kelgan har qanday xabarni katta harflarga o‘girib qaytarsin. Server va klient qismlarini alohida fayllarda yozing.
# 48. `[PyQt5]` Foydalanuvchi ismini kiritganda "Xush kelibsiz, [ism]!" deb `QMessageBox` dialog oynasi ko‘rsatadigan dastur yozing. Maydon bo‘sh qoldirilsa ogohlantirish bering.
# 49. `[Socket]` Klient serverga o‘z nomini yuborsin, server barcha ulangan klientlar ro‘yxatini qaytarsin. `threading` yordamida bir nechta klientni bir vaqtda qabul qiluvchi server yozing.
# 50. `[PyQt5 + Socket]` IP manzil va port kiritib serverga ulana oladigan, xabar yubora oladigan va javobni oyna ichida ko‘ra oladigan minimal `GUI chat klient` dastur yozing.
# 51. `[NumPy]` 1 dan 100 gacha sonlardan iborat 10×10 matritsa yarating. Har qator va har ustunning o‘rtacha qiymatini, umumiy maksimum va minimumni hisoblang va ekranga chiqaring.
# 52. `[Pandas]` 5 ta talaba va 4 ta fan bahosidan iborat `DataFrame` tuzing. Har bir talabaning o‘rtacha balini hisoblang va "A’lo/Yaxshi/Qoniqarli" ustunini qo‘shing.
# 53. `[Matplotlib]` Uchta shahar uchun 12 oylik harorat ma’lumotlarini bir grafikda ko‘rsating. Har shahar uchun turli rang va marker ishlatib, `legend`, sarlavha va o‘q nomlari qo‘shing.
# 54. `[Scikit-learn]` `Iris` dataset ustida `Logistic Regression` modeli o‘rgating. `Accuracy` va `Confusion Matrix` ni hisoblang va natijani `matplotlib` bilan vizualizatsiya qiling.
# 55. `[Scikit-learn]` Uy narxlarini bashorat qiluvchi oddiy `Linear Regression` modeli tuzing. `MSE` va `R²` ni hisoblang, haqiqiy va bashorat qilingan qiymatlarni grafikda ko‘rsating.
# 56. `[Pandas + Seaborn]` Ochiq datasetdan foydalanib: `NaN` qiymatlarni toping va to‘ldiring, kategorik ustun uchun `value_counts()` chiqaring va natijani `bar chart` da ko‘rsating.
# 57. `[K-means]` `NumPy` yordamida 2 o‘lchamli tasodifiy 100 ta nuqta generatsiya qiling, `K-means` bilan 3 ta klasterga ajrating va har klasterni boshqa rangda `scatter plot` da ko‘rsating.
# 58. `[Decision Tree]` `Decision Tree` klassifikatori o‘rgating. `max_depth=3` va `max_depth=10` uchun `train/test accuracy` ni solishtiring va `overfitting` ni grafik orqali ko‘rsating.
# 59. `[NumPy + Matplotlib]` `Sin` va `cos` funksiyalarini [0, 4π] oraliqda 200 nuqta bilan hisoblang va ikkalasini bir grafikda turli rang va `label` bilan ko‘rsating. `Grid` va `legend` qo‘shing.
# 60. `[Sklearn Pipeline]` `StandardScaler` va `MLPClassifier` dan iborat `Pipeline` tuzing. `sklearn.datasets` dagi `wine`, `breast_cancer` yoki `digits` dataset ustida o‘rgating va `cross_val_score` bilan baholang.
