# %%
from IPython.display import display, HTML

display(HTML("""
<style>
    /* 1. UMUMIY KONTEYNER VA SHRIFT */
    .rendered_html, .jp-RenderedHTMLCommon, .jp-RenderedMarkdown {
        font-family: "Times New Roman", Times, serif !important;
        color: black !important;
        font-feature-settings: "kern" 1, "liga" 1, "clig" 1, "dlig" 1 !important;
        -webkit-font-smoothing: antialiased !important;
    }

    /* 2. MATNLAR: 1.5 oraliq, abzats va ro‘yxatlar */
    .rendered_html p, .jp-RenderedHTMLCommon p {
        font-family: "Times New Roman", Times, serif !important;
        font-size: 14pt !important;
        line-height: 1.5 !important;
        text-align: justify !important;
        text-indent: 1.25cm !important; /* Faqat p uchun abzats */
        margin: 0 !important;
    }

    /* Ro‘yxatlar uchun maxsus (nuqtalarni qaytarish) */
    .rendered_html ul, .jp-RenderedHTMLCommon ul {
        list-style-type: disc !important;
        margin-left: 2.5cm !important; /* Nuqtalar ko‘rinishi uchun surish */
        padding: 0 !important;
        text-indent: 0 !important;
    }

    .rendered_html li, .jp-RenderedHTMLCommon li {
        display: list-item !important; /* Block-dan list-item-ga qaytarish */
        font-family: "Times New Roman", Times, serif !important;
        font-size: 14pt !important;
        line-height: 1.5 !important;
        text-indent: 0 !important;
        margin: 0 !important;
    }

    .rendered_html p, .jp-RenderedHTMLCommon p {
        text-indent: 1.25cm !important;
    }

    /* 3. SARLAVHALAR: Markazda */
    .rendered_html h1, .jp-RenderedHTMLCommon h1,
    .rendered_html h2, .jp-RenderedHTMLCommon h2,
    .rendered_html h3, .jp-RenderedHTMLCommon h3,
    .rendered_html h4, .jp-RenderedHTMLCommon h4 {
        font-family: "Times New Roman", Times, serif !important;
        text-align: center !important;
        text-indent: 0 !important;
        margin: 0.5em 0 !important;
        font-weight: bold !important;
    }
    
    /* 4. KOD BLOKLARI VA PROMPTLARNI (In/Out) YASHIRISH */
    :root {
        --jp-code-font-size: 12pt !important;
    }

    /* "In [ ]" va "Out [ ]" yozuvlarini butunlay yo‘qotish */
    .jp-InputPrompt, .jp-OutputPrompt, .prompt, .input_prompt, .output_prompt {
        display: none !important;
        width: 0 !important;
        visibility: hidden !important;
    }

    /* Kod bloklarini chap chekkaga taqash */
    .jp-CodeCell .jp-Cell-inputWrapper, .cell.code_cell .input {
        margin-left: 0 !important;
        padding-left: 0 !important;
    }

    /* Sliderni yo‘qotish va qatorni majburan sindirish */
    .jp-CodeMirror, .CodeMirror, .CodeMirror-scroll, .CodeMirror-sizer, .CodeMirror-lines,
    .jp-OutputArea-output pre, .output_area pre, 
    .CodeMirror-code, .CodeMirror-line,
    code, kbd, samp {
        font-family: "Consolas", monospace !important;
        font-size: 12pt !important;
        text-indent: 0 !important;
        line-height: 1.3 !important;
        white-space: pre-wrap !important;
        word-wrap: break-word !important;
        word-break: break-all !important;
        overflow-x: visible !important;
        height: auto !important;
    }

    /* 5. BIRINCHI KATAKCHANI YASHIRISH VA TANLANGANDA OCHISH */
    /* Odatiy holatda mutlaqo yashirin va umuman joy egallamaydi */
    .jp-Notebook .jp-Cell:first-child:not(.jp-mod-selected), 
    .container div.cell.code_cell:first-of-type:not(.selected) {
        position: absolute !important;
        height: 0 !important;
        min-height: 0 !important;
        width: 0 !important;
        margin: 0 !important;
        padding: 0 !important;
        border: none !important;
        overflow: hidden !important;
        opacity: 0 !important;
        pointer-events: none !important;
        visibility: hidden !important;
    }


    /* Katakcha tanlanganda (Ctrl+A bosilganda) to‘liq ochiladi */
    .jp-Notebook .jp-Cell:first-child.jp-mod-selected,
    .container div.cell.code_cell:first-of-type.selected {
        position: relative !important;
        height: auto !important;
        width: 100% !important;
        opacity: 1 !important;
        overflow: visible !important;
        pointer-events: auto !important;
        visibility: visible !important;
    }
    
    /* Jadvallar ichidagi matnlarni 14pt qilish */
    .rendered_html table, .jp-RenderedHTMLCommon table,
    .rendered_html td, .jp-RenderedHTMLCommon td,
    .rendered_html th, .jp-RenderedHTMLCommon th {
        font-family: "Times New Roman", Times, serif !important;
        font-size: 14pt !important;
        line-height: 1.5 !important;
        color: black !important;
    }
    code, kbd, samp {
        white-space: nowrap !important;
    }
</style>
"""))
# Out:
# <style>
#     /* 1. UMUMIY KONTEYNER VA SHRIFT */
#     .rendered_html, .jp-RenderedHTMLCommon, .jp-RenderedMarkdown {
#         font-family: "Times New Roman", Times, serif !important;
#         color: black !important;
#         font-feature-settings: "kern" 1, "liga" 1, "clig" 1, "dlig" 1 !important;
#         -webkit-font-smoothing: antialiased !important;
#     }
#
#     /* 2. MATNLAR: 1.5 oraliq, abzats va ro‘yxatlar */
#     .rendered_html p, .jp-RenderedHTMLCommon p {
#         font-family: "Times New Roman", Times, serif !important;
#         font-size: 14pt !important;
#         line-height: 1.5 !important;
#         text-align: justify !important;
#         text-indent: 1.25cm !important; /* Faqat p uchun abzats */
#         margin: 0 !important;
#     }
#
#     /* Ro‘yxatlar uchun maxsus (nuqtalarni qaytarish) */
#     .rendered_html ul, .jp-RenderedHTMLCommon ul {
#         list-style-type: disc !important;
# ...

# %% [markdown]
# **Kirish**
#
# Biz mashinali o‘qitish (machine learning) modellari qanday ishlashi va ular qanday qo‘llanilishi haqida umumiy sharh bilan boshlaymiz. Agar siz ilgari statistik modellashtirish yoki mashinali o‘qitish bilan shug‘ullangan bo‘lsangiz, bu sizga juda oddiy tuyulishi mumkin. Xavotir olmang, biz tez orada kuchliroq modellarni qurishga o‘tamiz.
#
# Ushbu kurs davomida siz quyidagi ssenariy asosida modellar qurasiz:
#
# Sizning qarindoshingiz ko‘chmas mulk oldi-sotdisi bilan shug‘ullanib, millionlab dollar ishlab topgan. U sizning ma’lumotlar faniga (data science) bo‘lgan qiziqishingiz tufayli sizga biznes hamkorlikni taklif qildi. U mablag‘ni ta’minlaydi, siz esa turli uylarning qancha turishini bashorat qiluvchi modellarni yaratib berasiz.
#
# Siz qarindoshingizdan o‘tmishda ko‘chmas mulk narxlarini qanday bashorat qilganini so‘raysiz va u buni shunchaki intuitsiya deb aytadi. Biroq, qo‘shimcha savollar shuni ko‘rsatadiki, u o‘zi ko‘rgan uylar bo‘yicha narxlar qonuniyatlarini aniqlagan va u o‘zi ko‘rib chiqayotgan yangi uylar uchun bashorat qilishda ana shu qonuniyatlardan foydalanadi.
#
# Mashinali o‘qitish ham xuddi shunday ishlaydi. Biz "Qarorlar daraxti" (Decision Tree) deb nomlangan modeldan boshlaymiz. Undan ham aniqroq bashorat qiladigan murakkabroq modellar mavjud. Ammo qarorlar daraxtlarini tushunish oson va ular ma’lumotlar fanidagi eng yaxshi modellarning asosiy negizi hisoblanadi.
#
# Soddalik uchun, biz eng oddiy qarorlar daraxti bilan boshlaymiz.

# %% [markdown]
# <div style="display: flex; flex-direction: column; align-items: center;">
#     <img src="images/1.png" width="500">
# </div>

# %% [markdown]
# U uylarni faqat ikkita toifaga ajratadi. Ko‘rib chiqilayotgan har qanday uy uchun bashorat qilingan narx — bu o‘sha toifadagi uylarning tarixiy o‘rtacha narxidir.
#
# Biz uylarni ikki guruhga qanday ajratishni va keyin har bir guruhda bashorat qilinadigan narxni aniqlashni hal qilish uchun ma’lumotlardan foydalanamiz. Ma’lumotlardan qonuniyatlarni aniqlashning bu bosqichi modelni **moslashtirish (fitting)** yoki **o‘qitish (training)** deb ataladi. Modelni moslashtirish uchun foydalanilgan ma’lumotlar **o‘qitish ma’lumotlari (training data)** deyiladi.
#
# Model qanday moslashtirilishi (masalan, ma’lumotlarni qanday ajratish) haqidagi tafsilotlar yetarlicha murakkab bo‘lgani uchun, biz buni keyinroq ko‘rib chiqamiz. Model moslashtirilgandan so‘ng, siz uni yangi ma’lumotlarga qo‘llab, qo‘shimcha uylarning narxini bashorat qilishingiz mumkin.
#
# **Qarorlar daraxtini takomillashtirish**
#
# Ko‘chmas mulk bo‘yicha o‘qitish ma’lumotlarini moslashtirish natijasida quyidagi ikki qarorlar daraxtidan qaysi biri kelib chiqishi ehtimoli ko‘proq?

# %% [markdown]
# <div style="display: flex; flex-direction: column; align-items: center;">
#     <img src="images/2.png" width="800">
# </div>

# %% [markdown]
# Chap tomondagi qarorlar daraxti (1-qarorlar daraxti) ko‘proq mantiqqa ega, chunki u ko‘proq yotoqxonaga ega uylar kamroq yotoqxonaga ega uylarga qaraganda qimmatroq sotilishini aks ettiradi. Bu modelning eng katta kamchiligi shundaki, u uy narxiga ta’sir qiluvchi aksariyat omillarni, masalan, hammomlar soni, uchastka hajmi (lot size), joylashuvi va hokazolarni hisobga olmaydi.
#
# Siz ko‘proq "bo‘linishlarga" (splits) ega bo‘lgan daraxt yordamida ko‘proq omillarni qamrab olishingiz mumkin. Bular "chuqurroq" daraxtlar deb ataladi. Har bir uyning umumiy uchastka hajmini ham hisobga oladigan qarorlar daraxti quyidagicha ko‘rinishi mumkin:

# %% [markdown]
# <div style="display: flex; flex-direction: column; align-items: center;">
#     <img src="images/3.png" width="800">
# </div>

# %% [markdown]
# Siz har qanday uyning narxini qarorlar daraxti bo‘ylab yo‘nalishni kuzatib borish orqali bashorat qilasiz, bunda har doim uyning xususiyatlariga mos keladigan yo‘lni tanlaysiz. Uy uchun bashorat qilingan narx daraxtning eng pastki qismida joylashgan bo‘ladi. Daraxtning pastki qismidagi bashorat qilinadigan nuqta **barg (leaf)** deb ataladi.
#
# Daraxtdagi bo‘linishlar va barglardagi qiymatlar ma’lumotlar asosida aniqlanadi, shuning uchun endi siz ishlaydigan ma’lumotlarni ko‘rib chiqish vaqti keldi.
