# %%
from IPython.display import display, HTML

display(HTML("""
<style>
    /* 1. UMUMIY KONTEYNER VA SHRIFT */
    .rendered_html, .jp-RenderedHTMLCommon, .jp-RenderedMarkdown {
        font-family: "Times New Roman", Times, serif !important;
        color: black !important;
        font-feature-settings: "kern" 1, "liga" 1, "clig" 1, "dlig" 1 !important;
        -webkit-font-smoothing: antialiased !important;
    }

    /* 2. MATNLAR: 1.5 oraliq, abzats va ro‘yxatlar */
    .rendered_html p, .jp-RenderedHTMLCommon p {
        font-family: "Times New Roman", Times, serif !important;
        font-size: 14pt !important;
        line-height: 1.5 !important;
        text-align: justify !important;
        text-indent: 1.25cm !important; /* Faqat p uchun abzats */
        margin: 0 !important;
    }

    /* Ro‘yxatlar uchun maxsus (nuqtalarni qaytarish) */
    .rendered_html ul, .jp-RenderedHTMLCommon ul {
        list-style-type: disc !important;
        margin-left: 2.5cm !important; /* Nuqtalar ko‘rinishi uchun surish */
        padding: 0 !important;
        text-indent: 0 !important;
    }

    .rendered_html li, .jp-RenderedHTMLCommon li {
        display: list-item !important; /* Block-dan list-item-ga qaytarish */
        font-family: "Times New Roman", Times, serif !important;
        font-size: 14pt !important;
        line-height: 1.5 !important;
        text-indent: 0 !important;
        margin: 0 !important;
    }

    .rendered_html p, .jp-RenderedHTMLCommon p {
        text-indent: 1.25cm !important;
    }

    /* 3. SARLAVHALAR: Markazda */
    .rendered_html h1, .jp-RenderedHTMLCommon h1,
    .rendered_html h2, .jp-RenderedHTMLCommon h2,
    .rendered_html h3, .jp-RenderedHTMLCommon h3,
    .rendered_html h4, .jp-RenderedHTMLCommon h4 {
        font-family: "Times New Roman", Times, serif !important;
        text-align: center !important;
        text-indent: 0 !important;
        margin: 0.5em 0 !important;
        font-weight: bold !important;
    }
    
    /* 4. KOD BLOKLARI VA PROMPTLARNI (In/Out) YASHIRISH */
    :root {
        --jp-code-font-size: 12pt !important;
    }

    /* "In [ ]" va "Out [ ]" yozuvlarini butunlay yo‘qotish */
    .jp-InputPrompt, .jp-OutputPrompt, .prompt, .input_prompt, .output_prompt {
        display: none !important;
        width: 0 !important;
        visibility: hidden !important;
    }

    /* Kod bloklarini chap chekkaga taqash */
    .jp-CodeCell .jp-Cell-inputWrapper, .cell.code_cell .input {
        margin-left: 0 !important;
        padding-left: 0 !important;
    }

    /* Sliderni yo‘qotish va qatorni majburan sindirish */
    .jp-CodeMirror, .CodeMirror, .CodeMirror-scroll, .CodeMirror-sizer, .CodeMirror-lines,
    .jp-OutputArea-output pre, .output_area pre, 
    .CodeMirror-code, .CodeMirror-line,
    code, kbd, samp {
        font-family: "Consolas", monospace !important;
        font-size: 12pt !important;
        text-indent: 0 !important;
        line-height: 1.3 !important;
        white-space: pre-wrap !important;
        word-wrap: break-word !important;
        word-break: break-all !important;
        overflow-x: visible !important;
        height: auto !important;
    }

    /* 5. BIRINCHI KATAKCHANI YASHIRISH VA TANLANGANDA OCHISH */
    /* Odatiy holatda mutlaqo yashirin va umuman joy egallamaydi */
    .jp-Notebook .jp-Cell:first-child:not(.jp-mod-selected), 
    .container div.cell.code_cell:first-of-type:not(.selected) {
        position: absolute !important;
        height: 0 !important;
        min-height: 0 !important;
        width: 0 !important;
        margin: 0 !important;
        padding: 0 !important;
        border: none !important;
        overflow: hidden !important;
        opacity: 0 !important;
        pointer-events: none !important;
        visibility: hidden !important;
    }


    /* Katakcha tanlanganda (Ctrl+A bosilganda) to‘liq ochiladi */
    .jp-Notebook .jp-Cell:first-child.jp-mod-selected,
    .container div.cell.code_cell:first-of-type.selected {
        position: relative !important;
        height: auto !important;
        width: 100% !important;
        opacity: 1 !important;
        overflow: visible !important;
        pointer-events: auto !important;
        visibility: visible !important;
    }
    
    /* Jadvallar ichidagi matnlarni 14pt qilish */
    .rendered_html table, .jp-RenderedHTMLCommon table,
    .rendered_html td, .jp-RenderedHTMLCommon td,
    .rendered_html th, .jp-RenderedHTMLCommon th {
        font-family: "Times New Roman", Times, serif !important;
        font-size: 14pt !important;
        line-height: 1.5 !important;
        color: black !important;
    }
    code, kbd, samp {
        white-space: nowrap !important;
    }
</style>
"""))
# Out:
# <style>
#     /* 1. UMUMIY KONTEYNER VA SHRIFT */
#     .rendered_html, .jp-RenderedHTMLCommon, .jp-RenderedMarkdown {
#         font-family: "Times New Roman", Times, serif !important;
#         color: black !important;
#         font-feature-settings: "kern" 1, "liga" 1, "clig" 1, "dlig" 1 !important;
#         -webkit-font-smoothing: antialiased !important;
#     }
#
#     /* 2. MATNLAR: 1.5 oraliq, abzats va ro‘yxatlar */
#     .rendered_html p, .jp-RenderedHTMLCommon p {
#         font-family: "Times New Roman", Times, serif !important;
#         font-size: 14pt !important;
#         line-height: 1.5 !important;
#         text-align: justify !important;
#         text-indent: 1.25cm !important; /* Faqat p uchun abzats */
#         margin: 0 !important;
#     }
#
#     /* Ro‘yxatlar uchun maxsus (nuqtalarni qaytarish) */
#     .rendered_html ul, .jp-RenderedHTMLCommon ul {
#         list-style-type: disc !important;
# ...

# %% [markdown]
# <div style="font-family: ’Times New Roman’, Times, serif; color: black; line-height: 1.4; width: 100%; max-width: 850px; margin: auto;">
#     <h2 style="text-align: center; font-weight: bold; font-size: 18pt; text-transform: uppercase; margin-bottom: 30px;">Mundarija</h2>
#     <div style="margin-bottom: 10px; font-size: 14pt; font-weight: bold; padding-left: 0cm; clear: both; overflow: hidden;">
#         <div style="position: relative; overflow: hidden;">
#             <span style="background: white; padding-right: 5px;  position: relative; z-index: 1; display: inline; text-transform: uppercase;">
#                 I BOB. Kirish (Introduction)
#             </span>
#             <span style="float: right; background: white; padding-left: 5px; position: relative; z-index: 1;">17</span>
#             <div style="position: absolute; bottom: 4px; left: 0; right: 0; border-bottom: 2px dotted black; z-index: 0;"></div>
#         </div>
#     </div>
#     <div style="margin-bottom: 10px; font-size: 14pt; padding-left: 1cm; clear: both; overflow: hidden; position: relative;">
#         <div style="position: relative; overflow: hidden;">
#             <span style="background: white; padding-right: 5px; position: relative; z-index: 1; display: inline;">
#                 1.1. Mashinali o‘qitishga kirish (Introduction to Machine Learning)
#             </span>
#             <span style="float: right; background: white; padding-left: 5px; position: relative; z-index: 1;">5</span>
#             <div style="position: absolute; bottom: 4px; left: 0; right: 0; border-bottom: 2px dotted black; z-index: 0;"></div>
#         </div>
#     </div>
#     <div style="margin-bottom: 10px; font-size: 14pt; padding-left: 1cm; clear: both; overflow: hidden; position: relative;">
#         <div style="position: relative; overflow: hidden;">
#             <span style="background: white; padding-right: 5px; position: relative; z-index: 1; display: inline;">
#                 1.2. Nazoratsiz o‘qitish haqida umumiy tushuncha (Overview of Unsupervised Learning)
#             </span>
#             <span style="float: right; background: white; padding-left: 5px; position: relative; z-index: 1;">5</span>
#             <div style="position: absolute; bottom: 4px; left: 0; right: 0; border-bottom: 2px dotted black; z-index: 0;"></div>
#         </div>
#     </div>
#     <div style="margin-bottom: 10px; font-size: 14pt; padding-left: 1cm; clear: both; overflow: hidden; position: relative;">
#         <div style="position: relative; overflow: hidden;">
#             <span style="background: white; padding-right: 5px; position: relative; z-index: 1; display: inline;">
#                 1.3. Kuchaytirish orqali o‘qitish haqida umumiy tushuncha (Overview of Reinforcement Learning)
#             </span>
#             <span style="float: right; background: white; padding-left: 5px; position: relative; z-index: 1;">5</span>
#             <div style="position: absolute; bottom: 4px; left: 0; right: 0; border-bottom: 2px dotted black; z-index: 0;"></div>
#         </div>
#     </div>
#     <div style="margin-bottom: 10px; font-size: 14pt; padding-left: 1cm; clear: both; overflow: hidden; position: relative;">
#         <div style="position: relative; overflow: hidden;">
#             <span style="background: white; padding-right: 5px; position: relative; z-index: 1; display: inline;">
#                 1.4. O‘zini-o‘zi nazorat qilib o‘qitish (Self-Supervised Learning)
#             </span>
#             <span style="float: right; background: white; padding-left: 5px; position: relative; z-index: 1;">5</span>
#             <div style="position: absolute; bottom: 4px; left: 0; right: 0; border-bottom: 2px dotted black; z-index: 0;"></div>
#         </div>
#     </div>
#     <div style="margin-bottom: 10px; font-size: 14pt; padding-left: 1cm; clear: both; overflow: hidden; position: relative;">
#         <div style="position: relative; overflow: hidden;">
#             <span style="background: white; padding-right: 5px; position: relative; z-index: 1; display: inline;">
#                 1.5. Qisman nazorat ostida o‘qitish (Semi-Supervised Learning)
#             </span>
#             <span style="float: right; background: white; padding-left: 5px; position: relative; z-index: 1;">5</span>
#             <div style="position: absolute; bottom: 4px; left: 0; right: 0; border-bottom: 2px dotted black; z-index: 0;"></div>
#         </div>
#     </div>

# %% [markdown]
# <div style="font-family: ’Times New Roman’, Times, serif; color: black; line-height: 1.4; width: 100%; max-width: 850px; margin: auto;">
#     <div style="margin-bottom: 10px; font-size: 14pt; font-weight: bold; padding-left: 0cm; clear: both; overflow: hidden;">
#         <div style="position: relative; overflow: hidden;">
#             <span style="background: white; padding-right: 5px;  position: relative; z-index: 1; display: inline; text-transform: uppercase;">
#                 II BOB. Mashinali o‘qitish tizimi (Machine Learning Pipeline)
#             </span>
#             <span style="float: right; background: white; padding-left: 5px; position: relative; z-index: 1;">17</span>
#             <div style="position: absolute; bottom: 4px; left: 0; right: 0; border-bottom: 2px dotted black; z-index: 0;"></div>
#         </div>
#     </div>
#     <div style="margin-bottom: 10px; font-size: 14pt; padding-left: 1cm; clear: both; overflow: hidden;">
#         <div style="position: relative; overflow: hidden;">
#             <span style="background: white; padding-right: 5px; position: relative; z-index: 1; display: inline;">
#                 2.1. Ma’lumotlarni dastlabki qayta ishlash (Data Preprocessing)
#             </span>
#             <span style="float: right; background: white; padding-left: 5px; position: relative; z-index: 1;">14</span>
#             <div style="position: absolute; bottom: 4px; left: 0; right: 0; border-bottom: 2px dotted black; z-index: 0;"></div>
#         </div>
#     </div>
#     <div style="margin-bottom: 10px; font-size: 14pt; padding-left: 2.5cm; clear: both; overflow: hidden;">
#         <div style="position: relative; overflow: hidden;">
#             <span style="background: white; padding-right: 5px; font-style: italic; position: relative; z-index: 1; display: inline;">
#                 2.1.1. Mashinali o‘qitish ish jarayoni (Machine Learning Workflow)
#             </span>
#             <span style="float: right; background: white; padding-left: 5px; position: relative; z-index: 1;">7</span>
#             <div style="position: absolute; bottom: 4px; left: 0; right: 0; border-bottom: 2px dotted black; z-index: 0;"></div>
#         </div>
#     </div>
#     <div style="margin-bottom: 10px; font-size: 14pt; padding-left: 2.5cm; clear: both; overflow: hidden;">
#         <div style="position: relative; overflow: hidden;">
#             <span style="background: white; padding-right: 5px; font-style: italic; position: relative; z-index: 1; display: inline;">
#                 2.1.2. Ma’lumotlarni tozalash (Data Cleaning)
#             </span>
#             <span style="float: right; background: white; padding-left: 5px; position: relative; z-index: 1;">7</span>
#             <div style="position: absolute; bottom: 4px; left: 0; right: 0; border-bottom: 2px dotted black; z-index: 0;"></div>
#         </div>
#     </div>
#     <div style="margin-bottom: 10px; font-size: 14pt; padding-left: 2.5cm; clear: both; overflow: hidden;">
#         <div style="position: relative; overflow: hidden;">
#             <span style="background: white; padding-right: 5px; font-style: italic; position: relative; z-index: 1; display: inline;">
#                 2.1.3. Python'da ma’lumotlarni dastlabki qayta ishlash (Data Preprocessing in Python)
#             </span>
#             <span style="float: right; background: white; padding-left: 5px; position: relative; z-index: 1;">7</span>
#             <div style="position: absolute; bottom: 4px; left: 0; right: 0; border-bottom: 2px dotted black; z-index: 0;"></div>
#         </div>
#     </div>
#     <div style="margin-bottom: 10px; font-size: 14pt; padding-left: 2.5cm; clear: both; overflow: hidden;">
#         <div style="position: relative; overflow: hidden;">
#             <span style="background: white; padding-right: 5px; font-style: italic; position: relative; z-index: 1; display: inline;">
#                 2.1.4. Xususiyatlarni masshtablash (Feature Scaling)
#             </span>
#             <span style="float: right; background: white; padding-left: 5px; position: relative; z-index: 1;">7</span>
#             <div style="position: absolute; bottom: 4px; left: 0; right: 0; border-bottom: 2px dotted black; z-index: 0;"></div>
#         </div>
#     </div>
#     <div style="margin-bottom: 10px; font-size: 14pt; padding-left: 2.5cm; clear: both; overflow: hidden;">
#         <div style="position: relative; overflow: hidden;">
#             <span style="background: white; padding-right: 5px; font-style: italic; position: relative; z-index: 1; display: inline;">
#                 2.1.5. Xususiyatlarni ajratib olish (Feature Extraction)
#             </span>
#             <span style="float: right; background: white; padding-left: 5px; position: relative; z-index: 1;">7</span>
#             <div style="position: absolute; bottom: 4px; left: 0; right: 0; border-bottom: 2px dotted black; z-index: 0;"></div>
#         </div>
#     </div>
#     <div style="margin-bottom: 10px; font-size: 14pt; padding-left: 2.5cm; clear: both; overflow: hidden;">
#         <div style="position: relative; overflow: hidden;">
#             <span style="background: white; padding-right: 5px; font-style: italic; position: relative; z-index: 1; display: inline;">
#                 2.1.6. Xususiyatlar muhandisligi (Feature Engineering)
#             </span>
#             <span style="float: right; background: white; padding-left: 5px; position: relative; z-index: 1;">7</span>
#             <div style="position: absolute; bottom: 4px; left: 0; right: 0; border-bottom: 2px dotted black; z-index: 0;"></div>
#         </div>
#     </div>
#     <div style="margin-bottom: 10px; font-size: 14pt; padding-left: 2.5cm; clear: both; overflow: hidden;">
#         <div style="position: relative; overflow: hidden;">
#             <span style="background: white; padding-right: 5px; font-style: italic; position: relative; z-index: 1; display: inline;">
#                 2.1.7. Xususiyatlarni tanlash usullari (Feature Selection Techniques)
#             </span>
#             <span style="float: right; background: white; padding-left: 5px; position: relative; z-index: 1;">7</span>
#             <div style="position: absolute; bottom: 4px; left: 0; right: 0; border-bottom: 2px dotted black; z-index: 0;"></div>
#         </div>
#     </div>
#     <div style="margin-bottom: 10px; font-size: 14pt; padding-left: 1cm; clear: both; overflow: hidden;">
#         <div style="position: relative; overflow: hidden;">
#             <span style="background: white; padding-right: 5px; position: relative; z-index: 1; display: inline;">
#                 2.2. Ma’lumotlarni dastlabki o‘rganish (Exploratory Data Analysis)
#             </span>
#             <span style="float: right; background: white; padding-left: 5px; position: relative; z-index: 1;">17</span>
#             <div style="position: absolute; bottom: 4px; left: 0; right: 0; border-bottom: 2px dotted black; z-index: 0;"></div>
#         </div>
#     </div>
#     <div style="margin-bottom: 10px; font-size: 14pt; padding-left: 2.5cm; clear: both; overflow: hidden;">
#         <div style="position: relative; overflow: hidden;">
#             <span style="background: white; padding-right: 5px; font-style: italic; position: relative; z-index: 1; display: inline;">
#                 2.2.1. Ma’lumotlarni dastlabki o‘rganish (Exploratory Data Analysis)
#             </span>
#             <span style="float: right; background: white; padding-left: 5px; position: relative; z-index: 1;">7</span>
#             <div style="position: absolute; bottom: 4px; left: 0; right: 0; border-bottom: 2px dotted black; z-index: 0;"></div>
#         </div>
#     </div>
#     <div style="margin-bottom: 10px; font-size: 14pt; padding-left: 2.5cm; clear: both; overflow: hidden;">
#         <div style="position: relative; overflow: hidden;">
#             <span style="background: white; padding-right: 5px; font-style: italic; position: relative; z-index: 1; display: inline;">
#                 2.2.2. Python'da ma’lumotlarni dastlabki o‘rganish (Exploratory Data Analysis in Python)
#             </span>
#             <span style="float: right; background: white; padding-left: 5px; position: relative; z-index: 1;">7</span>
#             <div style="position: absolute; bottom: 4px; left: 0; right: 0; border-bottom: 2px dotted black; z-index: 0;"></div>
#         </div>
#     </div>
#     <div style="margin-bottom: 10px; font-size: 14pt; padding-left: 2.5cm; clear: both; overflow: hidden;">
#         <div style="position: relative; overflow: hidden;">
#             <span style="background: white; padding-right: 5px; font-style: italic; position: relative; z-index: 1; display: inline;">
#                 2.2.3. Murakkab ma’lumotlarni dastlabki o‘rganish (Advanced EDA)
#             </span>
#             <span style="float: right; background: white; padding-left: 5px; position: relative; z-index: 1;">7</span>
#             <div style="position: absolute; bottom: 4px; left: 0; right: 0; border-bottom: 2px dotted black; z-index: 0;"></div>
#         </div>
#     </div>
#     <div style="margin-bottom: 10px; font-size: 14pt; padding-left: 2.5cm; clear: both; overflow: hidden;">
#         <div style="position: relative; overflow: hidden;">
#             <span style="background: white; padding-right: 5px; font-style: italic; position: relative; z-index: 1; display: inline;">
#                 2.2.4. Vaqtli qatorlar ma’lumotlarini vizualizatsiya qilish (Time Series Data Visualization)
#             </span>
#             <span style="float: right; background: white; padding-left: 5px; position: relative; z-index: 1;">7</span>
#             <div style="position: absolute; bottom: 4px; left: 0; right: 0; border-bottom: 2px dotted black; z-index: 0;"></div>
#         </div>
#     </div>
#     <div style="margin-bottom: 10px; font-size: 14pt; padding-left: 1cm; clear: both; overflow: hidden;">
#         <div style="position: relative; overflow: hidden;">
#             <span style="background: white; padding-right: 5px; position: relative; z-index: 1; display: inline;">
#                 2.3. Modelni baholash (Model Evaluation)
#             </span>
#             <span style="float: right; background: white; padding-left: 5px; position: relative; z-index: 1;">17</span>
#             <div style="position: absolute; bottom: 4px; left: 0; right: 0; border-bottom: 2px dotted black; z-index: 0;"></div>
#         </div>
#     </div>
#     <div style="margin-bottom: 10px; font-size: 14pt; padding-left: 2.5cm; clear: both; overflow: hidden;">
#         <div style="position: relative; overflow: hidden;">
#             <span style="background: white; padding-right: 5px; font-style: italic; position: relative; z-index: 1; display: inline;">
#                 2.3.1. Mashinali o‘qitishda regulyarizatsiya (Regularization in Machine Learning)
#             </span>
#             <span style="float: right; background: white; padding-left: 5px; position: relative; z-index: 1;">7</span>
#             <div style="position: absolute; bottom: 4px; left: 0; right: 0; border-bottom: 2px dotted black; z-index: 0;"></div>
#         </div>
#     </div>
#     <div style="margin-bottom: 10px; font-size: 14pt; padding-left: 1cm; clear: both; overflow: hidden;">
#         <div style="position: relative; overflow: hidden;">
#             <span style="background: white; padding-right: 5px; position: relative; z-index: 1; display: inline;">
#                 2.4. Nuqtali grafiklar (Scatter Plots)
#             </span>
#             <span style="float: right; background: white; padding-left: 5px; position: relative; z-index: 1;">17</span>
#             <div style="position: absolute; bottom: 4px; left: 0; right: 0; border-bottom: 2px dotted black; z-index: 0;"></div>
#         </div>
#     </div>
#     <div style="margin-bottom: 10px; font-size: 14pt; padding-left: 1cm; clear: both; overflow: hidden;">
#         <div style="position: relative; overflow: hidden;">
#             <span style="background: white; padding-right: 5px; position: relative; z-index: 1; display: inline;">
#                 2.5. Gistogrammalar (Histograms)
#             </span>
#             <span style="float: right; background: white; padding-left: 5px; position: relative; z-index: 1;">17</span>
#             <div style="position: absolute; bottom: 4px; left: 0; right: 0; border-bottom: 2px dotted black; z-index: 0;"></div>
#         </div>
#     </div>
#     <div style="margin-bottom: 10px; font-size: 14pt; padding-left: 1cm; clear: both; overflow: hidden;">
#         <div style="position: relative; overflow: hidden;">
#             <span style="background: white; padding-right: 5px; position: relative; z-index: 1; display: inline;">
#                 2.6. Doiraviy diagrammalar (Pie Charts)
#             </span>
#             <span style="float: right; background: white; padding-left: 5px; position: relative; z-index: 1;">17</span>
#             <div style="position: absolute; bottom: 4px; left: 0; right: 0; border-bottom: 2px dotted black; z-index: 0;"></div>
#         </div>
#     </div>
# </div>

# %% [markdown]
# <div style="font-family: ’Times New Roman’, Times, serif; color: black; line-height: 1.4; width: 100%; max-width: 850px; margin: auto;">
#     <div style="margin-bottom: 10px; font-size: 14pt; font-weight: bold; padding-left: 0cm; clear: both; overflow: hidden;">
#         <div style="position: relative; overflow: hidden;">
#             <span style="background: white; padding-right: 5px;  position: relative; z-index: 1; display: inline; text-transform: uppercase;">
#                 III BOB. Grafiklarni sozlash (Customizing Plots)
#             </span>
#             <span style="float: right; background: white; padding-left: 5px; position: relative; z-index: 1;">17</span>
#             <div style="position: absolute; bottom: 4px; left: 0; right: 0; border-bottom: 2px dotted black; z-index: 0;"></div>
#         </div>
#     </div>
#     <div style="margin-bottom: 10px; font-size: 14pt; padding-left: 1cm; clear: both; overflow: hidden;">
#         <div style="position: relative; overflow: hidden;">
#             <span style="background: white; padding-right: 5px; position: relative; z-index: 1; display: inline;">
#                 3.1. Markerlar (Markers)
#             </span>
#             <span style="float: right; background: white; padding-left: 5px; position: relative; z-index: 1;">14</span>
#             <div style="position: absolute; bottom: 4px; left: 0; right: 0; border-bottom: 2px dotted black; z-index: 0;"></div>
#         </div>
#     </div>
#     <div style="margin-bottom: 10px; font-size: 14pt; padding-left: 1cm; clear: both; overflow: hidden;">
#         <div style="position: relative; overflow: hidden;">
#             <span style="background: white; padding-right: 5px;  position: relative; z-index: 1; display: inline;">
#                 3.2. Yorliqlarni qo‘shish (Adding Labels)
#             </span>
#             <span style="float: right; background: white; padding-left: 5px; position: relative; z-index: 1;">17</span>
#             <div style="position: absolute; bottom: 4px; left: 0; right: 0; border-bottom: 2px dotted black; z-index: 0;"></div>
#         </div>
#     </div>
#     <div style="margin-bottom: 10px; font-size: 14pt; padding-left: 1cm; clear: both; overflow: hidden;">
#         <div style="position: relative; overflow: hidden;">
#             <span style="background: white; padding-right: 5px;  position: relative; z-index: 1; display: inline;">
#                 3.3. To‘rlarni sozlash (Configuring Grid)
#             </span>
#             <span style="float: right; background: white; padding-left: 5px; position: relative; z-index: 1;">17</span>
#             <div style="position: absolute; bottom: 4px; left: 0; right: 0; border-bottom: 2px dotted black; z-index: 0;"></div>
#         </div>
#     </div>
#     <div style="margin-bottom: 10px; font-size: 14pt; padding-left: 1cm; clear: both; overflow: hidden;">
#         <div style="position: relative; overflow: hidden;">
#             <span style="background: white; padding-right: 5px;  position: relative; z-index: 1; display: inline;">
#                 3.4. Quyi grafiklarni yaratish (Creating Subplots)
#             </span>
#             <span style="float: right; background: white; padding-left: 5px; position: relative; z-index: 1;">17</span>
#             <div style="position: absolute; bottom: 4px; left: 0; right: 0; border-bottom: 2px dotted black; z-index: 0;"></div>
#         </div>
#     </div>
#     <div style="margin-bottom: 10px; font-size: 14pt; padding-left: 1cm; clear: both; overflow: hidden;">
#         <div style="position: relative; overflow: hidden;">
#             <span style="background: white; padding-right: 5px;  position: relative; z-index: 1; display: inline;">
#                 3.5. Grafiklar ko‘rinishini sozlash (Styling Plots)
#             </span>
#             <span style="float: right; background: white; padding-left: 5px; position: relative; z-index: 1;">17</span>
#             <div style="position: absolute; bottom: 4px; left: 0; right: 0; border-bottom: 2px dotted black; z-index: 0;"></div>
#         </div>
#     </div>
#     <div style="margin-bottom: 10px; font-size: 14pt; padding-left: 1cm; clear: both; overflow: hidden;">
#         <div style="position: relative; overflow: hidden;">
#             <span style="background: white; padding-right: 5px;  position: relative; z-index: 1; display: inline;">
#                 3.6. Grafik o‘lchamini o‘zgartirish (Resize a Plot)
#             </span>
#             <span style="float: right; background: white; padding-left: 5px; position: relative; z-index: 1;">17</span>
#             <div style="position: absolute; bottom: 4px; left: 0; right: 0; border-bottom: 2px dotted black; z-index: 0;"></div>
#         </div>
#     </div>
#     <div style="margin-bottom: 10px; font-size: 14pt; padding-left: 1cm; clear: both; overflow: hidden;">
#         <div style="position: relative; overflow: hidden;">
#             <span style="background: white; padding-right: 5px;  position: relative; z-index: 1; display: inline;">
#                 3.7. Grafik shaffofligini sozlash (Adjust Plot Transparency)
#             </span>
#             <span style="float: right; background: white; padding-left: 5px; position: relative; z-index: 1;">17</span>
#             <div style="position: absolute; bottom: 4px; left: 0; right: 0; border-bottom: 2px dotted black; z-index: 0;"></div>
#         </div>
#     </div>
#     <div style="margin-bottom: 10px; font-size: 14pt; padding-left: 1cm; clear: both; overflow: hidden;">
#         <div style="position: relative; overflow: hidden;">
#             <span style="background: white; padding-right: 5px;  position: relative; z-index: 1; display: inline;">
#                 3.8. Shriftlarni o‘zgartirish (Change Fonts)
#             </span>
#             <span style="float: right; background: white; padding-left: 5px; position: relative; z-index: 1;">17</span>
#             <div style="position: absolute; bottom: 4px; left: 0; right: 0; border-bottom: 2px dotted black; z-index: 0;"></div>
#         </div>
#     </div>
#     <div style="margin-bottom: 10px; font-size: 14pt; padding-left: 1cm; clear: both; overflow: hidden;">
#         <div style="position: relative; overflow: hidden;">
#             <span style="background: white; padding-right: 5px;  position: relative; z-index: 1; display: inline;">
#                 3.9. Shkala yozuvlari shrift o‘lchamini sozlash (Setting Tick Label Font Size)
#             </span>
#             <span style="float: right; background: white; padding-left: 5px; position: relative; z-index: 1;">17</span>
#             <div style="position: absolute; bottom: 4px; left: 0; right: 0; border-bottom: 2px dotted black; z-index: 0;"></div>
#         </div>
#     </div>
#     <div style="margin-bottom: 10px; font-size: 14pt; padding-left: 1cm; clear: both; overflow: hidden;">
#         <div style="position: relative; overflow: hidden;">
#             <span style="background: white; padding-right: 5px;  position: relative; z-index: 1; display: inline;">
#                 3.10. Grafik fon rangini o‘zgartirish (Change Plot Background Color)
#             </span>
#             <span style="float: right; background: white; padding-left: 5px; position: relative; z-index: 1;">17</span>
#             <div style="position: absolute; bottom: 4px; left: 0; right: 0; border-bottom: 2px dotted black; z-index: 0;"></div>
#         </div>
#     </div>
#     <div style="margin-bottom: 10px; font-size: 14pt; padding-left: 1cm; clear: both; overflow: hidden;">
#         <div style="position: relative; overflow: hidden;">
#             <span style="background: white; padding-right: 5px;  position: relative; z-index: 1; display: inline;">
#                 3.11. O‘q yorliqlari joyini o‘zgartirish (Move Axis Labels)
#             </span>
#             <span style="float: right; background: white; padding-left: 5px; position: relative; z-index: 1;">17</span>
#             <div style="position: absolute; bottom: 4px; left: 0; right: 0; border-bottom: 2px dotted black; z-index: 0;"></div>
#         </div>
#     </div>
#     <div style="margin-bottom: 10px; font-size: 14pt; padding-left: 1cm; clear: both; overflow: hidden;">
#         <div style="position: relative; overflow: hidden;">
#             <span style="background: white; padding-right: 5px;  position: relative; z-index: 1; display: inline;">
#                 3.12. O‘qlarni, chegaralarni va ortiqcha bo‘shliqlarni yashirish (Hide Axis, Borders & Extra Space)
#             </span>
#             <span style="float: right; background: white; padding-left: 5px; position: relative; z-index: 1;">17</span>
#             <div style="position: absolute; bottom: 4px; left: 0; right: 0; border-bottom: 2px dotted black; z-index: 0;"></div>
#         </div>
#     </div>
# </div>

# %% [markdown]
# <div style="font-family: ’Times New Roman’, Times, serif; color: black; line-height: 1.4; width: 100%; max-width: 850px; margin: auto;">
#     <div style="margin-bottom: 10px; font-size: 14pt; font-weight: bold; padding-left: 0cm; clear: both; overflow: hidden;">
#         <div style="position: relative; overflow: hidden;">
#             <span style="background: white; padding-right: 5px;  position: relative; z-index: 1; display: inline; text-transform: uppercase;">
#                 IV BOB. Murakkab grafiklar chizish (Advanced Plotting)
#             </span>
#             <span style="float: right; background: white; padding-left: 5px; position: relative; z-index: 1;">17</span>
#             <div style="position: absolute; bottom: 4px; left: 0; right: 0; border-bottom: 2px dotted black; z-index: 0;"></div>
#         </div>
#     </div>
#     <div style="margin-bottom: 10px; font-size: 14pt; padding-left: 1cm; clear: both; overflow: hidden;">
#         <div style="position: relative; overflow: hidden;">
#             <span style="background: white; padding-right: 5px;  position: relative; z-index: 1; display: inline;">
#                 4.1. 3D grafiklar yaratish (Creating 3D Plots)
#             </span>
#             <span style="float: right; background: white; padding-left: 5px; position: relative; z-index: 1;">14</span>
#             <div style="position: absolute; bottom: 4px; left: 0; right: 0; border-bottom: 2px dotted black; z-index: 0;"></div>
#         </div>
#     </div>
#     <div style="margin-bottom: 10px; font-size: 14pt; padding-left: 1cm; clear: both; overflow: hidden;">
#         <div style="position: relative; overflow: hidden;">
#             <span style="background: white; padding-right: 5px;  position: relative; z-index: 1; display: inline;">
#                 4.2. Sirtli va to‘rsimon grafiklar (Surface & Wireframe Plots)
#             </span>
#             <span style="float: right; background: white; padding-left: 5px; position: relative; z-index: 1;">17</span>
#             <div style="position: absolute; bottom: 4px; left: 0; right: 0; border-bottom: 2px dotted black; z-index: 0;"></div>
#         </div>
#     </div>
#     <div style="margin-bottom: 10px; font-size: 14pt; padding-left: 1cm; clear: both; overflow: hidden;">
#         <div style="position: relative; overflow: hidden;">
#             <span style="background: white; padding-right: 5px;  position: relative; z-index: 1; display: inline;">
#                 4.3. Issiqlik xaritalari va kontur grafiklar (Heatmaps & Contour Plots)
#             </span>
#             <span style="float: right; background: white; padding-left: 5px; position: relative; z-index: 1;">17</span>
#             <div style="position: absolute; bottom: 4px; left: 0; right: 0; border-bottom: 2px dotted black; z-index: 0;"></div>
#         </div>
#     </div>
#     <div style="margin-bottom: 10px; font-size: 14pt; padding-left: 1cm; clear: both; overflow: hidden;">
#         <div style="position: relative; overflow: hidden;">
#             <span style="background: white; padding-right: 5px;  position: relative; z-index: 1; display: inline;">
#                 4.4. Grafiklarni animatsiya qilish (Animating Plots)
#             </span>
#             <span style="float: right; background: white; padding-left: 5px; position: relative; z-index: 1;">17</span>
#             <div style="position: absolute; bottom: 4px; left: 0; right: 0; border-bottom: 2px dotted black; z-index: 0;"></div>
#         </div>
#     </div>
# </div>

# %% [markdown]
# <div style="font-family: ’Times New Roman’, Times, serif; color: black; line-height: 1.4; width: 100%; max-width: 850px; margin: auto;">
#     <div style="margin-bottom: 10px; font-size: 14pt; font-weight: bold; padding-left: 0cm; clear: both; overflow: hidden;">
#         <div style="position: relative; overflow: hidden;">
#             <span style="background: white; padding-right: 5px;  position: relative; z-index: 1; display: inline; text-transform: uppercase;">
#                 V BOB. Grafiklarni saqlash va eksport qilish (Saving and Exporting Plots)
#             </span>
#             <span style="float: right; background: white; padding-left: 5px; position: relative; z-index: 1;">17</span>
#             <div style="position: absolute; bottom: 4px; left: 0; right: 0; border-bottom: 2px dotted black; z-index: 0;"></div>
#         </div>
#     </div>
#     <div style="margin-bottom: 10px; font-size: 14pt; padding-left: 1cm; clear: both; overflow: hidden;">
#         <div style="position: relative; overflow: hidden;">
#             <span style="background: white; padding-right: 5px;  position: relative; z-index: 1; display: inline;">
#                 5.1. Grafiklarni PNG, JPG va SVG formatlarida saqlash (Saving Plots as PNG, JPG & SVG)
#             </span>
#             <span style="float: right; background: white; padding-left: 5px; position: relative; z-index: 1;">14</span>
#             <div style="position: absolute; bottom: 4px; left: 0; right: 0; border-bottom: 2px dotted black; z-index: 0;"></div>
#         </div>
#     </div>
#     <div style="margin-bottom: 10px; font-size: 14pt; padding-left: 1cm; clear: both; overflow: hidden;">
#         <div style="position: relative; overflow: hidden;">
#             <span style="background: white; padding-right: 5px;  position: relative; z-index: 1; display: inline;">
#                 5.2. Grafiklarni PDF formatida saqlash (Exporting Plots to PDF)
#             </span>
#             <span style="float: right; background: white; padding-left: 5px; position: relative; z-index: 1;">17</span>
#             <div style="position: absolute; bottom: 4px; left: 0; right: 0; border-bottom: 2px dotted black; z-index: 0;"></div>
#         </div>
#     </div>
#     <div style="margin-bottom: 10px; font-size: 14pt; padding-left: 1cm; clear: both; overflow: hidden;">
#         <div style="position: relative; overflow: hidden;">
#             <span style="background: white; padding-right: 5px;  position: relative; z-index: 1; display: inline;">
#                 5.3. Bir nechta grafiklarni saqlash (Saving Multiple Figures)
#             </span>
#             <span style="float: right; background: white; padding-left: 5px; position: relative; z-index: 1;">17</span>
#             <div style="position: absolute; bottom: 4px; left: 0; right: 0; border-bottom: 2px dotted black; z-index: 0;"></div>
#         </div>
#     </div>
# </div>

# %% [markdown]
# <div style="font-family: ’Times New Roman’, Times, serif; color: black; line-height: 1.4; width: 100%; max-width: 850px; margin: auto;">
#     <div style="margin-bottom: 10px; font-size: 14pt; font-weight: bold; padding-left: 0cm; clear: both; overflow: hidden;">
#         <div style="position: relative; overflow: hidden;">
#             <span style="background: white; padding-right: 5px;  position: relative; z-index: 1; display: inline; text-transform: uppercase;">
#                 VI BOB. Matplotlib asboblar to‘plami (Toolkits in Matplotlib)
#             </span>
#             <span style="float: right; background: white; padding-left: 5px; position: relative; z-index: 1;">17</span>
#             <div style="position: absolute; bottom: 4px; left: 0; right: 0; border-bottom: 2px dotted black; z-index: 0;"></div>
#         </div>
#     </div>
#     <div style="margin-bottom: 10px; font-size: 14pt; padding-left: 1cm; clear: both; overflow: hidden;">
#         <div style="position: relative; overflow: hidden;">
#             <span style="background: white; padding-right: 5px;  position: relative; z-index: 1; display: inline;">
#                 6.1. <code>Seaborn</code> kutubxonasi (<code>Seaborn</code> Library)
#             </span>
#             <span style="float: right; background: white; padding-left: 5px; position: relative; z-index: 1;">14</span>
#             <div style="position: absolute; bottom: 4px; left: 0; right: 0; border-bottom: 2px dotted black; z-index: 0;"></div>
#         </div>
#     </div>
#     <div style="margin-bottom: 10px; font-size: 14pt; padding-left: 1cm; clear: both; overflow: hidden;">
#         <div style="position: relative; overflow: hidden;">
#             <span style="background: white; padding-right: 5px;  position: relative; z-index: 1; display: inline;">
#                 6.2. <code>mplot3d</code> orqali 3D grafiklar (3D Plotting with <code>mplot3d</code>)
#             </span>
#             <span style="float: right; background: white; padding-left: 5px; position: relative; z-index: 1;">17</span>
#             <div style="position: absolute; bottom: 4px; left: 0; right: 0; border-bottom: 2px dotted black; z-index: 0;"></div>
#         </div>
#     </div>
# </div>

# %% [markdown]
# <div style="font-family: ’Times New Roman’, Times, serif; color: black; line-height: 1.4; width: 100%; max-width: 850px; margin: auto;">
#     <div style="margin-bottom: 10px; font-size: 14pt; font-weight: bold; padding-left: 0cm; clear: both; overflow: hidden;">
#         <div style="position: relative; overflow: hidden;">
#             <span style="background: white; padding-right: 5px;  position: relative; z-index: 1; display: inline; text-transform: uppercase;">
#                 VII BOB. Matplotlib-ning Pandas va Seaborn bilan integratsiyasi (Matplotlib with Pandas and Seaborn)
#             </span>
#             <span style="float: right; background: white; padding-left: 5px; position: relative; z-index: 1;">17</span>
#             <div style="position: absolute; bottom: 4px; left: 0; right: 0; border-bottom: 2px dotted black; z-index: 0;"></div>
#         </div>
#     </div>
#     <div style="margin-bottom: 10px; font-size: 14pt; padding-left: 1cm; clear: both; overflow: hidden;">
#         <div style="position: relative; overflow: hidden;">
#             <span style="background: white; padding-right: 5px;  position: relative; z-index: 1; display: inline;">
#                 7.1. Pandas DataFrame-lari bilan Matplotlib (Matplotlib with Pandas DataFrames)
#             </span>
#             <span style="float: right; background: white; padding-left: 5px; position: relative; z-index: 1;">14</span>
#             <div style="position: absolute; bottom: 4px; left: 0; right: 0; border-bottom: 2px dotted black; z-index: 0;"></div>
#         </div>
#     </div>
#     <div style="margin-bottom: 10px; font-size: 14pt; padding-left: 1cm; clear: both; overflow: hidden;">
#         <div style="position: relative; overflow: hidden;">
#             <span style="background: white; padding-right: 5px;  position: relative; z-index: 1; display: inline;">
#                 7.2. Vaqtli qatorlar ma’lumotlarini vizuallashtirish (Visualizing Time Series Data)
#             </span>
#             <span style="float: right; background: white; padding-left: 5px; position: relative; z-index: 1;">17</span>
#             <div style="position: absolute; bottom: 4px; left: 0; right: 0; border-bottom: 2px dotted black; z-index: 0;"></div>
#         </div>
#     </div>
#     <div style="margin-bottom: 10px; font-size: 14pt; padding-left: 1cm; clear: both; overflow: hidden;">
#         <div style="position: relative; overflow: hidden;">
#             <span style="background: white; padding-right: 5px;  position: relative; z-index: 1; display: inline;">
#                 7.3. Seaborn va Matplotlib-ni birlashtirish (Combining Seaborn & Matplotlib)
#             </span>
#             <span style="float: right; background: white; padding-left: 5px; position: relative; z-index: 1;">17</span>
#             <div style="position: absolute; bottom: 4px; left: 0; right: 0; border-bottom: 2px dotted black; z-index: 0;"></div>
#         </div>
#     </div>
#     <div style="margin-bottom: 10px; font-size: 14pt; padding-left: 1cm; clear: both; overflow: hidden;">
#         <div style="position: relative; overflow: hidden;">
#             <span style="background: white; padding-right: 5px;  position: relative; z-index: 1; display: inline;">
#                 7.4. Juftlik grafiklarini yaratish (Creating Pair Plots)
#             </span>
#             <span style="float: right; background: white; padding-left: 5px; position: relative; z-index: 1;">17</span>
#             <div style="position: absolute; bottom: 4px; left: 0; right: 0; border-bottom: 2px dotted black; z-index: 0;"></div>
#         </div>
#     </div>
#     <div style="margin-bottom: 10px; font-size: 14pt; padding-left: 1cm; clear: both; overflow: hidden;">
#         <div style="position: relative; overflow: hidden;">
#             <span style="background: white; padding-right: 5px;  position: relative; z-index: 1; display: inline;">
#                 7.5. Korrelyatsiya issiqlik xaritalari (Correlation Heatmaps)
#             </span>
#             <span style="float: right; background: white; padding-left: 5px; position: relative; z-index: 1;">17</span>
#             <div style="position: absolute; bottom: 4px; left: 0; right: 0; border-bottom: 2px dotted black; z-index: 0;"></div>
#         </div>
#     </div>
# </div>

# %% [markdown]
# <div style="font-family: ’Times New Roman’, Times, serif; color: black; line-height: 1.4; width: 100%; max-width: 850px; margin: auto;">
#     <div style="margin-bottom: 10px; font-size: 14pt; font-weight: bold; padding-left: 0cm; clear: both; overflow: hidden;">
#         <div style="position: relative; overflow: hidden;">
#             <span style="background: white; padding-right: 5px;  position: relative; z-index: 1; display: inline; text-transform: uppercase;">
#                 VIII BOB. Test (Quiz)
#             </span>
#             <span style="float: right; background: white; padding-left: 5px; position: relative; z-index: 1;">17</span>
#             <div style="position: absolute; bottom: 4px; left: 0; right: 0; border-bottom: 2px dotted black; z-index: 0;"></div>
#         </div>
#     </div>
# </div>

# %% [markdown]
# <div style="font-family: ’Times New Roman’, Times, serif; color: black; line-height: 1.4; width: 100%; max-width: 850px; margin: auto;">
#     <div style="margin-bottom: 10px; font-size: 14pt; font-weight: bold; padding-left: 0cm; clear: both; overflow: hidden;">
#         <div style="position: relative; overflow: hidden;">
#             <span style="background: white; padding-right: 5px;  position: relative; z-index: 1; display: inline; text-transform: uppercase;">
#                 IX BOB. Loyihalar (Projects)
#             </span>
#             <span style="float: right; background: white; padding-left: 5px; position: relative; z-index: 1;">17</span>
#             <div style="position: absolute; bottom: 4px; left: 0; right: 0; border-bottom: 2px dotted black; z-index: 0;"></div>
#         </div>
#     </div>
#     <div style="margin-bottom: 10px; font-size: 14pt; padding-left: 1cm; clear: both; overflow: hidden;">
#         <div style="position: relative; overflow: hidden;">
#             <span style="background: white; padding-right: 5px;  position: relative; z-index: 1; display: inline;">
#                 9.1. 3D sinus to‘lqinini yaratish (Creating a 3D Sine Wave)
#             </span>
#             <span style="float: right; background: white; padding-left: 5px; position: relative; z-index: 1;">14</span>
#             <div style="position: absolute; bottom: 4px; left: 0; right: 0; border-bottom: 2px dotted black; z-index: 0;"></div>
#         </div>
#     </div>
#     <div style="margin-bottom: 10px; font-size: 14pt; padding-left: 1cm; clear: both; overflow: hidden;">
#         <div style="position: relative; overflow: hidden;">
#             <span style="background: white; padding-right: 5px;  position: relative; z-index: 1; display: inline;">
#                 9.2. Pufakchali saralashni vizuallashtirish (Visualizing Bubble Sort)
#             </span>
#             <span style="float: right; background: white; padding-left: 5px; position: relative; z-index: 1;">17</span>
#             <div style="position: absolute; bottom: 4px; left: 0; right: 0; border-bottom: 2px dotted black; z-index: 0;"></div>
#         </div>
#     </div>
#     <div style="margin-bottom: 10px; font-size: 14pt; padding-left: 1cm; clear: both; overflow: hidden;">
#         <div style="position: relative; overflow: hidden;">
#             <span style="background: white; padding-right: 5px;  position: relative; z-index: 1; display: inline;">
#                 9.3. Birlashtirib saralashni vizuallashtirish (Merge Sort Visualization)
#             </span>
#             <span style="float: right; background: white; padding-left: 5px; position: relative; z-index: 1;">17</span>
#             <div style="position: absolute; bottom: 4px; left: 0; right: 0; border-bottom: 2px dotted black; z-index: 0;"></div>
#         </div>
#     </div>
#     <div style="margin-bottom: 10px; font-size: 14pt; padding-left: 1cm; clear: both; overflow: hidden;">
#         <div style="position: relative; overflow: hidden;">
#             <span style="background: white; padding-right: 5px;  position: relative; z-index: 1; display: inline;">
#                 9.4. Tezkor saralashni vizuallashtirish (Quick Sort Visualization)
#             </span>
#             <span style="float: right; background: white; padding-left: 5px; position: relative; z-index: 1;">17</span>
#             <div style="position: absolute; bottom: 4px; left: 0; right: 0; border-bottom: 2px dotted black; z-index: 0;"></div>
#         </div>
#     </div>
#     <div style="margin-bottom: 10px; font-size: 14pt; padding-left: 1cm; clear: both; overflow: hidden;">
#         <div style="position: relative; overflow: hidden;">
#             <span style="background: white; padding-right: 5px;  position: relative; z-index: 1; display: inline;">
#                 9.5. 3D Tezkor saralashni vizuallashtirish (3D Quick Sort Visualization)
#             </span>
#             <span style="float: right; background: white; padding-left: 5px; position: relative; z-index: 1;">17</span>
#             <div style="position: absolute; bottom: 4px; left: 0; right: 0; border-bottom: 2px dotted black; z-index: 0;"></div>
#         </div>
#     </div>
#     <div style="margin-bottom: 10px; font-size: 14pt; padding-left: 1cm; clear: both; overflow: hidden;">
#         <div style="position: relative; overflow: hidden;">
#             <span style="background: white; padding-right: 5px;  position: relative; z-index: 1; display: inline;">
#                 9.6. 3D Birlashtirib saralashni vizuallashtirish (3D Merge Sort Visualization)
#             </span>
#             <span style="float: right; background: white; padding-left: 5px; position: relative; z-index: 1;">17</span>
#             <div style="position: absolute; bottom: 4px; left: 0; right: 0; border-bottom: 2px dotted black; z-index: 0;"></div>
#         </div>
#     </div>
#     <div style="margin-bottom: 10px; font-size: 14pt; padding-left: 1cm; clear: both; overflow: hidden;">
#         <div style="position: relative; overflow: hidden;">
#             <span style="background: white; padding-right: 5px;  position: relative; z-index: 1; display: inline;">
#                 9.7. 3D Kiritish orqali saralashni vizuallashtirish (3D Insertion Sort Visualization)
#             </span>
#             <span style="float: right; background: white; padding-left: 5px; position: relative; z-index: 1;">17</span>
#             <div style="position: absolute; bottom: 4px; left: 0; right: 0; border-bottom: 2px dotted black; z-index: 0;"></div>
#         </div>
#     </div>
#     <div style="margin-bottom: 10px; font-size: 14pt; padding-left: 1cm; clear: both; overflow: hidden;">
#         <div style="position: relative; overflow: hidden;">
#             <span style="background: white; padding-right: 5px;  position: relative; z-index: 1; display: inline;">
#                 9.8. Harakatlanuvchi o‘rtacha qiymatga ega vaqtli qatorlar grafigini yaratish (Create a Time Series Plot with Rolling Average)
#             </span>
#             <span style="float: right; background: white; padding-left: 5px; position: relative; z-index: 1;">17</span>
#             <div style="position: absolute; bottom: 4px; left: 0; right: 0; border-bottom: 2px dotted black; z-index: 0;"></div>
#         </div>
#     </div>
#     <div style="margin-bottom: 10px; font-size: 14pt; padding-left: 1cm; clear: both; overflow: hidden;">
#         <div style="position: relative; overflow: hidden;">
#             <span style="background: white; padding-right: 5px;  position: relative; z-index: 1; display: inline;">
#                 9.9. Turli tovushlarni grafikda tasvirlash (Plotting Different Sounds)
#             </span>
#             <span style="float: right; background: white; padding-left: 5px; position: relative; z-index: 1;">17</span>
#             <div style="position: absolute; bottom: 4px; left: 0; right: 0; border-bottom: 2px dotted black; z-index: 0;"></div>
#         </div>
#     </div>
#     <div style="margin-bottom: 10px; font-size: 14pt; padding-left: 1cm; clear: both; overflow: hidden;">
#         <div style="position: relative; overflow: hidden;">
#             <span style="background: white; padding-right: 5px;  position: relative; z-index: 1; display: inline;">
#                 9.10. COVID-19 ma’lumotlarini vizuallashtirish (Visualizing COVID-19 Data)
#             </span>
#             <span style="float: right; background: white; padding-left: 5px; position: relative; z-index: 1;">17</span>
#             <div style="position: absolute; bottom: 4px; left: 0; right: 0; border-bottom: 2px dotted black; z-index: 0;"></div>
#         </div>
#     </div>
#     <div style="margin-bottom: 10px; font-size: 14pt; padding-left: 1cm; clear: both; overflow: hidden;">
#         <div style="position: relative; overflow: hidden;">
#             <span style="background: white; padding-right: 5px;  position: relative; z-index: 1; display: inline;">
#                 9.11. Ishlatilgan (ikkinchi qo‘l) avtomobillar narxini tahlil qilish (Analyzing Used Car Prices)
#             </span>
#             <span style="float: right; background: white; padding-left: 5px; position: relative; z-index: 1;">17</span>
#             <div style="position: absolute; bottom: 4px; left: 0; right: 0; border-bottom: 2px dotted black; z-index: 0;"></div>
#         </div>
#     </div>
# </div>
