# %% [markdown]
# <div style="font-family: 'Times New Roman', Times, serif; color: black; line-height: 1.4; width: 100%; max-width: 850px; margin: auto;">
#     <h2 style="text-align: center; font-weight: bold; font-size: 18pt; text-transform: uppercase; margin-bottom: 30px;">Mundarija</h2>
#     <div style="margin-bottom: 15px; font-weight: bold; font-size: 14pt; overflow: hidden;">
#         <span style="float: left; background: white; padding-right: 5px;">1-BOB. TIZIMNING NAZARIY ASOSLARI VA ARXITEKTURASI</span>
#         <span style="float: right; background: white; padding-left: 5px; position: relative; z-index: 2;">4</span>
#         <div style="border-bottom: 2px dotted black; margin-top: 1.2em;"></div>
#     </div>
#     <div style="margin-bottom: 10px; font-size: 14pt; padding-left: 1.5cm; clear: both; overflow: hidden; position: relative;">
#         <div style="position: relative; overflow: hidden;">
#             <span style="background: white; padding-right: 5px; position: relative; z-index: 1; display: inline;">
#                 1.1. NumPy asoslari va bir o‘lchovli massivlar (1D Arrays)
#             </span>
#             <span style="float: right; background: white; padding-left: 5px; position: relative; z-index: 1;">6</span>
#             <div style="position: absolute; bottom: 4px; left: 0; right: 0; border-bottom: 2px dotted black; z-index: 0;"></div>
#         </div>
#     </div>
#     <div style="margin-bottom: 10px; font-size: 14pt; padding-left: 2.5cm; clear: both; overflow: hidden;">
#         <div style="position: relative; overflow: hidden;">
#             <span style="background: white; padding-right: 5px; font-style: italic; position: relative; z-index: 1; display: inline;">
#                 1.1.1. NumPy asoslari va massiv yaratish
#             </span>
#             <span style="float: right; background: white; padding-left: 5px; position: relative; z-index: 1;">7</span>
#             <div style="position: absolute; bottom: 4px; left: 0; right: 0; border-bottom: 2px dotted black; z-index: 0;"></div>
#         </div>
#     </div>
#     <div style="margin-bottom: 10px; font-size: 14pt; padding-left: 2.5cm; clear: both; overflow: hidden;">
#         <div style="position: relative; overflow: hidden;">
#             <span style="background: white; padding-right: 5px; font-style: italic; position: relative; z-index: 1; display: inline;">
#                 1.1.2. Indekslash (indexing) va qirqish (slicing)
#             </span>
#             <span style="float: right; background: white; padding-left: 5px; position: relative; z-index: 1;">7</span>
#             <div style="position: absolute; bottom: 4px; left: 0; right: 0; border-bottom: 2px dotted black; z-index: 0;"></div>
#         </div>
#     </div>
#     <div style="margin-bottom: 10px; font-size: 14pt; padding-left: 2.5cm; clear: both; overflow: hidden;">
#         <div style="position: relative; overflow: hidden;">
#             <span style="background: white; padding-right: 5px; font-style: italic; position: relative; z-index: 1; display: inline;">
#                 1.1.3. Asosiy operatsiyalar (Vektor amallari)
#             </span>
#             <span style="float: right; background: white; padding-left: 5px; position: relative; z-index: 1;">7</span>
#             <div style="position: absolute; bottom: 4px; left: 0; right: 0; border-bottom: 2px dotted black; z-index: 0;"></div>
#         </div>
#     </div>
#     <div style="margin-bottom: 10px; font-size: 14pt; padding-left: 2.5cm; clear: both; overflow: hidden;">
#         <div style="position: relative; overflow: hidden;">
#             <span style="background: white; padding-right: 5px; font-style: italic; position: relative; z-index: 1; display: inline;">
#                 1.1.4. Universal funksiyalar (Universal functions)
#             </span>
#             <span style="float: right; background: white; padding-left: 5px; position: relative; z-index: 1;">7</span>
#             <div style="position: absolute; bottom: 4px; left: 0; right: 0; border-bottom: 2px dotted black; z-index: 0;"></div>
#         </div>
#     </div>
#     <div style="margin-bottom: 10px; font-size: 14pt; padding-left: 2.5cm; clear: both; overflow: hidden;">
#         <div style="position: relative; overflow: hidden;">
#             <span style="background: white; padding-right: 5px; font-style: italic; position: relative; z-index: 1; display: inline;">
#                 1.1.5. Matematik funksiyalarni grafikda tasvirlash (Plotting)
#             </span>
#             <span style="float: right; background: white; padding-left: 5px; position: relative; z-index: 1;">7</span>
#             <div style="position: absolute; bottom: 4px; left: 0; right: 0; border-bottom: 2px dotted black; z-index: 0;"></div>
#         </div>
#     </div>
#     <div style="margin-top: 20px; margin-bottom: 15px; font-weight: bold; font-size: 14pt; overflow: hidden;">
#         <span style="float: left; background: white; padding-right: 5px;">2-BOB. MA’LUMOTLARNI UZATISH VA PAKETLASH ALGORITMLARI</span>
#         <span style="float: right; background: white; padding-left: 5px; position: relative; z-index: 2;">22</span>
#         <div style="border-bottom: 2px dotted black; margin-top: 1.2em;"></div>
#     </div>
#     <div style="margin-top: 30px; font-weight: bold; font-size: 14pt; overflow: hidden;">
#         <span style="float: left; background: white; padding-right: 5px;">XULOSA</span>
#         <span style="float: right; background: white; padding-left: 5px; position: relative; z-index: 2;">68</span>
#         <div style="border-bottom: 2px dotted black; margin-top: 1.2em;"></div>
#     </div>
# </div>
